# %%
import GUI
# %matplotlib nbagg

GUI.main(datafile='processed_data/venus_specData.npy', regionfile='data', orbitfile='orbits')
# Out:
# <img src="data:image/png;base64,..." width="900">
# VBox(children=(HBox(children=(Button(description='prev orbit', style=ButtonStyle()), Button(description='next …

# %%
import ipywidgets as widgets

progress = list()

progress.append(
widgets.FloatProgress(
    value=5.5,
    min=0,
    max=10.0,
    step=0.1,
    description='Overall:',
    bar_style='info',
    orientation='horizontal'
))

progress.append(
widgets.FloatProgress(
    value=7.5,
    min=0,
    max=10.0,
    step=0.1,
    description='Viktor:',
    bar_style='info',
    orientation='horizontal'
))

progress.append(
widgets.FloatProgress(
    value=9.5,
    min=0,
    max=10.0,
    step=0.1,
    description='Nicolas:',
    bar_style='info',
    orientation='horizontal'
))

progress.append(
widgets.FloatProgress(
    value=3.5,
    min=0,
    max=10.0,
    step=0.1,
    description='Alex:',
    bar_style='info',
    orientation='horizontal'
))

widgets.VBox(progress)
# Out:
# VBox(children=(FloatProgress(value=5.5, bar_style='info', description='Overall:', max=10.0), FloatProgress(val…
